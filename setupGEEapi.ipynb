# %%
import os

import getpass

#user = getpass.getuser()

#pw = getpass.getpass()

os.environ['http_proxy'] = "http://user:password@proxy-surf.loc.cnes.fr:8050"#.format(user,pw)

os.environ['https_proxy'] = "http://user:password@proxy-surf.loc.cnes.fr:8050"#.format(user,pw)

import requests
requests.get("https://google.com")
# Out:
# <Response [200]>

# %%
import ee
import osgeo

# %%
ee.Authenticate()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=kquX1lJc_hfqbQrrsGKGFu0pa3x7ILlC6MITqPcosdQ&tc=1z_DrMwnI8fTbo0dycXJRXM7rLrawP6A1z1sHh69E7A&cc=aoUIxgcyRmt-6ZRdhq9wgoy6MqveJaBKuNQOZHK8Yro>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=kquX1lJc_hfqbQrrsGKGFu0pa3x7ILlC6MITqPcosdQ&tc=1z_DrMwnI8fTbo0dycXJRXM7rLrawP6A1z1sHh69E7A&cc=aoUIxgcyRmt-6ZRdhq9wgoy6MqveJaBKuNQOZHK8Yro</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code:  4/1AVG7fiS_wpH1ek1Hd4Gug27LPNW_LMaetWJqzT3GedVFOsgiPg1P6KCrQ_I
# ...

# %%
ee.Initialize(project='idGEEproject')

# %%
print(ee.Image("NASA/NASADEM_HGT/001").get("title").getInfo())
# Out:
# NASADEM: NASA NASADEM Digital Elevation 30m
